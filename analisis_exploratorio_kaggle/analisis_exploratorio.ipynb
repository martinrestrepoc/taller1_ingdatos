# %% [markdown]
# # Análisis exploratorio del rendimiento de jugadores - FIFA World Cup 2026

# %% [markdown]
# ## 1. Importación de librerías

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Carga y selección de columnas
#
# El dataset completo contiene 70 columnas, por lo que se escogen algunas que permitan hacer análisis y correlación entre ellas.

# %%
columnas_seleccionadas = [
    'player_id',
    'match_id',
    'match_date',
    'team',
    'opponent_team',
    'position',
    'preferred_foot',
    'tournament_stage',
    'match_result',
    'age',
    'market_value_eur',
    'minutes_played',
    'goals',
    'assists',
    'expected_goals_xg',
    'pass_accuracy',
    'distance_covered_km',
    'player_rating'
]

# %%
data = pd.read_csv(
    'fifa_world_cup_2026_player_performance.csv',
    usecols=columnas_seleccionadas
)
data.head()
# Out:
#   player_id  age   team    position preferred_foot  market_value_eur match_id  \
# 0    P00055   26  Spain  Goalkeeper           Left           4384884   M00001
# 1    P00070   19  Spain  Midfielder          Right           4918927   M00001
# 2    P00066   18  Spain  Midfielder           Left         125015698   M00001
# 3    P00073   20  Spain     Forward          Right          11805512   M00001
# 4    P00059   23  Spain    Defender           Left          13325174   M00001
#
#    match_date opponent_team tournament_stage match_result  minutes_played  \
# 0  2026-07-10  South Africa      Group Stage            W              72
# 1  2026-07-10  South Africa      Group Stage            W              90
# 2  2026-07-10  South Africa      Group Stage            W              73
# 3  2026-07-10  South Africa      Group Stage            W              80
# 4  2026-07-10  South Africa      Group Stage            W              79
#
#    goals  assists  expected_goals_xg  pass_accuracy  distance_covered_km  \
# 0      0        0               0.00           0.59                  7.8
# 1      0        0               0.01           0.89                 10.4
# 2      1        0               0.08           0.85                  8.8
# 3      1        1               0.00           0.67                  9.6
# 4      0        0               0.00           0.76                  7.5
#
#    player_rating
# 0            5.6
# 1            5.7
# 2            8.3
# 3            6.9
# 4            5.7

# %% [markdown]
# # Descripción del Dataset

# %% [markdown]
# El dataset contiene información inventada sobre el desempeño individual de los jugadores durante los partidos de la Copa Mundial de la FIFA 2026. Las columnas seleccionadas describen el contexto del partido, las características del jugador y diferentes indicadores de rendimiento.

# %%
data.shape # Información sobre la cantidad de filas y columnas del dataset.
# Out:
# (54600, 18)

# %%
data.info() # Muestra el tipo de dato de cada columna y la cantidad de valores no nulos.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 54600 entries, 0 to 54599
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player_id            54600 non-null  str
#  1   age                  54600 non-null  int64
#  2   team                 54600 non-null  str
#  3   position             54600 non-null  str
#  4   preferred_foot       54600 non-null  str
#  5   market_value_eur     54600 non-null  int64
#  6   match_id             54600 non-null  str
#  7   match_date           54600 non-null  str
#  8   opponent_team        54600 non-null  str
#  9   tournament_stage     54600 non-null  str
#  10  match_result         54600 non-null  str
#  11  minutes_played       54600 non-null  int64
#  12  goals                54600 non-null  int64
#  13  assists              54600 non-null  int64
#  14  expected_goals_xg    54600 non-null  float64
#  15  pass_accuracy        54600 non-null  float64
#  16  distance_covered_km  54600 non-null  float64
#  17  player_rating        54600 non-null  float64
# dtypes: float64(4), int64(5), str(9)
# memory usage: 7.5 MB

# %%
data.sample(10) # Trae 10 filas aleatorias del dataset.
# Out:
#       player_id  age         team    position preferred_foot  \
# 1177     P00758   21      Jamaica    Defender          Right
# 9844     P00138   31  Netherlands    Defender          Right
# 8002     P01159   21      Tunisia  Midfielder           Left
# 4616     P00019   31       France  Midfielder          Right
# 46797    P00641   27         Peru  Midfielder          Right
# 32138    P00296   26       Serbia    Defender          Right
# 10120    P01143   19     Cameroon     Forward           Left
# 26338    P00443   23     Scotland  Goalkeeper          Right
# 43484    P00413   31       Turkey     Forward          Right
# 2355     P00129   27        Italy     Forward           Left
#
#        market_value_eur match_id  match_date opponent_team tournament_stage  \
# 1177           43256708   M00023  2026-07-14          Iraq      Group Stage
# 9844            3113021   M00190  2026-07-27       Ukraine      Group Stage
# 8002            3352021   M00154  2026-07-06         Ghana      Group Stage
# 4616           31444197   M00089  2026-07-02         Spain      Group Stage
# 46797           3565779   M00900  2026-06-19       Denmark   Quarter Finals
# 32138           8239354   M00619  2026-07-21       Morocco      Round of 32
# 10120          65761438   M00195  2026-07-18     Argentina      Group Stage
# 26338          13160802   M00507  2026-06-26       Nigeria      Group Stage
# 43484           2791716   M00837  2026-07-06       Tunisia      Round of 16
# 2355           11851880   M00046  2026-07-02         Spain      Group Stage
#
#       match_result  minutes_played  goals  assists  expected_goals_xg  \
# 1177             W              83      0        0               0.00
# 9844             W               0      0        0               0.00
# 8002             D               0      0        0               0.00
# 4616             W              23      0        0               0.00
# 46797            W               0      0        0               0.00
# 32138            D              80      0        0               0.00
# 10120            W              67      1        0               0.47
# 26338            L              71      0        0               0.00
# 43484            W              31      0        0               0.00
# 2355             L              22      1        0               0.00
#
#        pass_accuracy  distance_covered_km  player_rating
# 1177            0.94                  7.5            7.4
# 9844            0.96                  0.0            0.0
# 8002            0.83                  0.0            0.0
# 4616            0.85                  3.0            5.4
# 46797           0.80                  0.0            0.0
# 32138           0.78                  8.3            6.9
# 10120           0.61                  5.1            7.2
# 26338           0.84                  7.3            6.7
# 43484           0.82                  2.9            5.7
# 2355            0.82                  2.6            5.9

# %%
data.dtypes
# Out:
# player_id                  str
# age                      int64
# team                       str
# position                   str
# preferred_foot             str
# market_value_eur         int64
# match_id                   str
# match_date                 str
# opponent_team              str
# tournament_stage           str
# match_result               str
# minutes_played           int64
# goals                    int64
# assists                  int64
# expected_goals_xg      float64
# pass_accuracy          float64
# distance_covered_km    float64
# player_rating          float64
# dtype: object

# %% [markdown]
# ## 4. Granularidad e índice

# %% [markdown]
# Granularidad: Cada fila representa la actuación individual de un jugador en un partido específico de la Copa Mundial de la FIFA 2026.

# %%
data.duplicated(subset=['match_id', 'player_id']).sum() # Verifica si existen registros repetidos para un mismo jugador en un mismo partido.
# Out:
# np.int64(0)

# %%
data.set_index(['match_id', 'player_id'], inplace=True) # Establece el partido y el jugador como índice compuesto.

# %%
data.head()
# Out:
#                     age   team    position preferred_foot  market_value_eur  \
# match_id player_id
# M00001   P00055      26  Spain  Goalkeeper           Left           4384884
#          P00070      19  Spain  Midfielder          Right           4918927
#          P00066      18  Spain  Midfielder           Left         125015698
#          P00073      20  Spain     Forward          Right          11805512
#          P00059      23  Spain    Defender           Left          13325174
#
#                     match_date opponent_team tournament_stage match_result  \
# match_id player_id
# M00001   P00055     2026-07-10  South Africa      Group Stage            W
#          P00070     2026-07-10  South Africa      Group Stage            W
#          P00066     2026-07-10  South Africa      Group Stage            W
#          P00073     2026-07-10  South Africa      Group Stage            W
#          P00059     2026-07-10  South Africa      Group Stage            W
#
#                     minutes_played  goals  assists  expected_goals_xg  \
# match_id player_id
# M00001   P00055                 72      0        0               0.00
#          P00070                 90      0        0               0.01
#          P00066                 73      1        0               0.08
#          P00073                 80      1        1               0.00
#          P00059                 79      0        0               0.00
#
#                     pass_accuracy  distance_covered_km  player_rating
# match_id player_id
# M00001   P00055              0.59                  7.8            5.6
#          P00070              0.89                 10.4            5.7
#          P00066              0.85                  8.8            8.3
#          P00073              0.67                  9.6            6.9
#          P00059              0.76                  7.5            5.7

# %%
data.index.value_counts() # Muestra cuántas veces aparece cada combinación de partido y jugador.
# Out:
# match_id  player_id
# M00001    P00053       1
#           P00054       1
#           P00055       1
#           P00056       1
#           P00057       1
#                       ..
# M01050    P01036       1
#           P01037       1
#           P01038       1
#           P01039       1
#           P01040       1
# Name: count, Length: 54600, dtype: int64

# %% [markdown]
# ## 5. Clasificación de las variables

# %%
columns_date = ['match_date']

columns_categorical = [
    'team',
    'opponent_team',
    'position',
    'preferred_foot',
    'tournament_stage',
    'match_result'
]

columns_numerical = [
    'age',
    'market_value_eur',
    'minutes_played',
    'goals',
    'assists',
    'expected_goals_xg',
    'pass_accuracy',
    'distance_covered_km',
    'player_rating'
]

# %%
len(columns_date) + len(columns_categorical) + len(columns_numerical) == data.shape[1] # Verifica que todas las columnas de análisis estén clasificadas.
# Out:
# True

# %% [markdown]
# ## 6. Conversión de tipos de datos

# %%
for col_date in columns_date:
    data[col_date] = pd.to_datetime(data[col_date]) # Convierte las columnas de fecha a tipo datetime.

for col_categorical in columns_categorical:
    data[col_categorical] = data[col_categorical].astype('category') # Convierte las columnas categóricas a tipo category.

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# MultiIndex: 54600 entries, ('M00001', 'P00055') to ('M01050', 'P00989')
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  54600 non-null  int64
#  1   team                 54600 non-null  category
#  2   position             54600 non-null  category
#  3   preferred_foot       54600 non-null  category
#  4   market_value_eur     54600 non-null  int64
#  5   match_date           54600 non-null  datetime64[us]
#  6   opponent_team        54600 non-null  category
#  7   tournament_stage     54600 non-null  category
#  8   match_result         54600 non-null  category
#  9   minutes_played       54600 non-null  int64
#  10  goals                54600 non-null  int64
#  11  assists              54600 non-null  int64
#  12  expected_goals_xg    54600 non-null  float64
#  13  pass_accuracy        54600 non-null  float64
#  14  distance_covered_km  54600 non-null  float64
#  15  player_rating        54600 non-null  float64
# dtypes: category(6), datetime64[us](1), float64(4), int64(5)
# memory usage: 4.7+ MB

# %%
data.dtypes
# Out:
# age                             int64
# team                         category
# position                     category
# preferred_foot               category
# market_value_eur                int64
# match_date             datetime64[us]
# opponent_team                category
# tournament_stage             category
# match_result                 category
# minutes_played                  int64
# goals                           int64
# assists                         int64
# expected_goals_xg             float64
# pass_accuracy                 float64
# distance_covered_km           float64
# player_rating                 float64
# dtype: object

# %% [markdown]
# # Análisis Univariante

# %% [markdown]
# ## 7. Análisis univariante categórico

# %%
for col in columns_categorical:
    print(f"\n{'='*70}")
    print(f"ANÁLISIS DE: {col.upper()}")
    print(f"{'='*70}")

    # 1. Cantidad de categorías
    num_categories = data[col].nunique()
    print(f"\nCantidad de categorías: {num_categories}")

    # 2. Tabla de conteo y porcentajes
    value_counts = data[col].value_counts()
    percentage = (value_counts / len(data) * 100).round(2)

    table = pd.DataFrame({
        'Categoría': value_counts.index,
        'Conteo': value_counts.values,
        'Porcentaje (%)': percentage.values
    })
    table = table.reset_index(drop=True)
    print("\nTabla de conteo y porcentajes:")
    display(table)

    # 3. Gráficos para variables con menos de 10 categorías
    if num_categories < 10:
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))

        colors_array = plt.cm.Set2(range(num_categories))

        sns.countplot(
            data=data,
            x=col,
            ax=axes[0],
            order=value_counts.index,
            legend=False,
            width=0.75
        )

        for i, patch in enumerate(axes[0].patches):
            patch.set_facecolor(colors_array[i])

        axes[0].set_title(f'Conteo de {col}', fontsize=12, fontweight='bold')
        axes[0].set_xlabel(col, fontsize=10)
        axes[0].set_ylabel('Conteo', fontsize=10)
        axes[0].tick_params(axis='x', rotation=45)

        axes[1].pie(
            value_counts.values,
            labels=value_counts.index,
            autopct='%1.3f%%',
            startangle=180,
            colors=colors_array
        )
        axes[1].set_title(f'Distribución de {col}', fontsize=12, fontweight='bold')

        plt.tight_layout()
        plt.show()
    else:
        print(f"\nNota: {col} tiene {num_categories} categorías (≥10), no se generó gráfico.")
# Out:
# ======================================================================
# ANÁLISIS DE: TEAM
# ======================================================================
#
# Cantidad de categorías: 48
#
# Tabla de conteo y porcentajes:
#         Categoría  Conteo  Porcentaje (%)
# 0           Qatar    1716            3.14
# 1         Jamaica    1534            2.81
# 2         Morocco    1430            2.62
# 3     Netherlands    1404            2.57
# 4           Italy    1378            2.52
# 5    Saudi Arabia    1352            2.48
# 6         Belgium    1326            2.43
# 7          Turkey    1300            2.38
# 8         Croatia    1274            2.33
# 9        Scotland    1274            2.33
# 10         Canada    1248            2.29
# 11           Peru    1248            2.29
# 12      Australia    1222            2.24
# 13        Ecuador    1222            2.24
# 14         Panama    1222            2.24
# 15        Tunisia    1222            2.24
# 16       Colombia    1196            2.19
# 17     Costa Rica    1196            2.19
# 18         Brazil    1170            2.14
# 19          Egypt    1170            2.14
# 20          Ghana    1170            2.14
# 21          Spain    1170            2.14
# 22        Uruguay    1170            2.14
# 23       Cameroon    1144            2.10
# 24        England    1144            2.10
# 25     Uzbekistan    1144            2.10
# 26        Denmark    1118            2.05
# 27       Portugal    1118            2.05
# 28         Serbia    1092            2.00
# 29        Algeria    1066            1.95
# 30           Iraq    1066            1.95
# 31         Mexico    1040            1.90
# 32        Nigeria    1040            1.90
# 33         Poland    1014            1.86
# 34           Iran     988            1.81
# 35        Senegal     988            1.81
# 36        Ukraine     988            1.81
# 37  United States     988            1.81
# 38          Chile     962            1.76
# 39          Japan     936            1.71
# 40         Sweden     936            1.71
# 41   South Africa     910            1.67
# 42    Switzerland     910            1.67
# 43      Argentina     884            1.62
# 44         France     884            1.62
# 45        Germany     884            1.62
# 46    South Korea     884            1.62
# 47        Austria     858            1.57
# Nota: team tiene 48 categorías (≥10), no se generó gráfico.
#
# ======================================================================
# ANÁLISIS DE: OPPONENT_TEAM
# ======================================================================
#
# Cantidad de categorías: 48
#
# Tabla de conteo y porcentajes:
#         Categoría  Conteo  Porcentaje (%)
# 0           Qatar    1716            3.14
# 1         Jamaica    1534            2.81
# 2         Morocco    1430            2.62
# 3     Netherlands    1404            2.57
# 4           Italy    1378            2.52
# 5    Saudi Arabia    1352            2.48
# 6         Belgium    1326            2.43
# 7          Turkey    1300            2.38
# 8         Croatia    1274            2.33
# 9        Scotland    1274            2.33
# 10         Canada    1248            2.29
# 11           Peru    1248            2.29
# 12      Australia    1222            2.24
# 13        Ecuador    1222            2.24
# 14         Panama    1222            2.24
# 15        Tunisia    1222            2.24
# 16       Colombia    1196            2.19
# 17     Costa Rica    1196            2.19
# 18         Brazil    1170            2.14
# 19          Egypt    1170            2.14
# 20          Ghana    1170            2.14
# 21          Spain    1170            2.14
# 22        Uruguay    1170            2.14
# 23       Cameroon    1144            2.10
# 24        England    1144            2.10
# 25     Uzbekistan    1144            2.10
# 26        Denmark    1118            2.05
# 27       Portugal    1118            2.05
# 28         Serbia    1092            2.00
# 29        Algeria    1066            1.95
# 30           Iraq    1066            1.95
# 31         Mexico    1040            1.90
# 32        Nigeria    1040            1.90
# 33         Poland    1014            1.86
# 34           Iran     988            1.81
# 35        Senegal     988            1.81
# 36        Ukraine     988            1.81
# 37  United States     988            1.81
# 38          Chile     962            1.76
# 39          Japan     936            1.71
# 40         Sweden     936            1.71
# 41   South Africa     910            1.67
# 42    Switzerland     910            1.67
# 43      Argentina     884            1.62
# 44         France     884            1.62
# 45        Germany     884            1.62
# 46    South Korea     884            1.62
# 47        Austria     858            1.57
# Nota: opponent_team tiene 48 categorías (≥10), no se generó gráfico.
#
# ======================================================================
# ANÁLISIS DE: POSITION
# ======================================================================
#
# Cantidad de categorías: 4
#
# Tabla de conteo y porcentajes:
#     Categoría  Conteo  Porcentaje (%)
# 0    Defender   18900           34.62
# 1  Midfielder   16800           30.77
# 2     Forward   12600           23.08
# 3  Goalkeeper    6300           11.54
# ======================================================================
# ANÁLISIS DE: PREFERRED_FOOT
# ======================================================================
#
# Cantidad de categorías: 2
#
# Tabla de conteo y porcentajes:
#   Categoría  Conteo  Porcentaje (%)
# 0     Right   40656           74.46
# 1      Left   13944           25.54
# ======================================================================
# ANÁLISIS DE: TOURNAMENT_STAGE
# ======================================================================
#
# Cantidad de categorías: 7
#
# Tabla de conteo y porcentajes:
#            Categoría  Conteo  Porcentaje (%)
# 0        Group Stage   30056           55.05
# 1        Round of 32    9256           16.95
# 2        Round of 16    6552           12.00
# 3     Quarter Finals    4368            8.00
# 4        Semi Finals    2184            4.00
# 5              Final    1092            2.00
# 6  Third Place Match    1092            2.00
# ======================================================================
# ANÁLISIS DE: MATCH_RESULT
# ======================================================================
#
# Cantidad de categorías: 3
#
# Tabla de conteo y porcentajes:
#   Categoría  Conteo  Porcentaje (%)
# 0         L   20124           36.86
# 1         W   20124           36.86
# 2         D   14352           26.29

# %% [markdown]
# ## 8. Análisis univariante numérico

# %%
for col in columns_numerical:
    print(f"\n{'='*70}")
    print(f"ANÁLISIS DE: {col.upper()}")
    print(f"{'='*70}")

    # Tabla de estadística descriptiva
    stats = data[col].describe().to_frame().T
    print("\nEstadística descriptiva:")
    display(stats)

    # Histograma y boxplot
    fig, axes = plt.subplots(2, 1, figsize=(10, 8))

    sns.histplot(data=data, x=col, ax=axes[0], color='steelblue')
    axes[0].set_title(f'Histograma de {col}', fontsize=12, fontweight='bold')
    axes[0].set_xlabel(col, fontsize=10)
    axes[0].set_ylabel('Frecuencia', fontsize=10)

    sns.boxplot(data=data, x=col, ax=axes[1], color='steelblue')
    axes[1].set_title(f'Boxplot de {col}', fontsize=12, fontweight='bold')
    axes[1].set_xlabel(col, fontsize=10)

    plt.tight_layout()
    plt.show()
# Out:
# ======================================================================
# ANÁLISIS DE: AGE
# ======================================================================
#
# Estadística descriptiva:
#        count       mean       std   min   25%   50%   75%   max
# age  54600.0  26.296484  4.067519  17.0  23.0  26.0  29.0  39.0
# ======================================================================
# ANÁLISIS DE: MARKET_VALUE_EUR
# ======================================================================
#
# Estadística descriptiva:
#                     count          mean           std       min        25%  \
# market_value_eur  54600.0  2.008445e+07  2.718866e+07  528822.0  4444778.0
#
#                          50%         75%          max
# market_value_eur  10271107.0  23420128.0  200000000.0
# ======================================================================
# ANÁLISIS DE: MINUTES_PLAYED
# ======================================================================
#
# Estadística descriptiva:
#                   count       mean        std  min  25%   50%   75%   max
# minutes_played  54600.0  36.199817  36.419755  0.0  0.0  24.0  75.0  90.0
# ======================================================================
# ANÁLISIS DE: GOALS
# ======================================================================
#
# Estadística descriptiva:
#          count      mean     std  min  25%  50%  75%  max
# goals  54600.0  0.055385  0.2519  0.0  0.0  0.0  0.0  4.0
# ======================================================================
# ANÁLISIS DE: ASSISTS
# ======================================================================
#
# Estadística descriptiva:
#            count      mean       std  min  25%  50%  75%  max
# assists  54600.0  0.052363  0.239021  0.0  0.0  0.0  0.0  3.0
# ======================================================================
# ANÁLISIS DE: EXPECTED_GOALS_XG
# ======================================================================
#
# Estadística descriptiva:
#                      count      mean       std  min  25%  50%  75%   max
# expected_goals_xg  54600.0  0.016112  0.074648  0.0  0.0  0.0  0.0  2.31
# ======================================================================
# ANÁLISIS DE: PASS_ACCURACY
# ======================================================================
#
# Estadística descriptiva:
#                  count     mean       std   min   25%   50%   75%   max
# pass_accuracy  54600.0  0.80844  0.074286  0.42  0.76  0.82  0.86  0.97
# ======================================================================
# ANÁLISIS DE: DISTANCE_COVERED_KM
# ======================================================================
#
# Estadística descriptiva:
#                        count      mean       std  min  25%  50%  75%   max
# distance_covered_km  54600.0  3.996504  4.023194  0.0  0.0  3.0  7.9  14.0
# ======================================================================
# ANÁLISIS DE: PLAYER_RATING
# ======================================================================
#
# Estadística descriptiva:
#                  count    mean       std  min  25%  50%  75%  max
# player_rating  54600.0  3.6347  3.155846  0.0  0.0  5.5  6.4  9.4

# %% [markdown]
# ## 9. Análisis univariante temporal

# %% [markdown]
# Los conteos de esta sección representan registros jugador-partido. No representan directamente la cantidad de partidos disputados en cada fecha.

# %%
for col in columns_date:
    print(f"\n{'='*70}")
    print(f"ANÁLISIS DE: {col.upper()}")
    print(f"{'='*70}")

    # Fecha mínima y máxima
    print(f"\nFecha mínima: {data[col].min()}")
    print(f"Fecha máxima: {data[col].max()}")

    # Fecha con más registros jugador-partido
    registros_por_fecha = data[col].value_counts()
    print(
        f"Fecha con más registros jugador-partido: {registros_por_fecha.index[0]} "
        f"({registros_por_fecha.iloc[0]} registros)"
    )

    fig, axes = plt.subplots(3, 1, figsize=(12, 12))

    # Distribución por año
    sns.countplot(x=data[col].dt.year, ax=axes[0], color='steelblue')
    axes[0].set_title('Distribución por año', fontsize=12, fontweight='bold')
    axes[0].set_xlabel('Año', fontsize=10)
    axes[0].set_ylabel('Cantidad de registros', fontsize=10)

    # Distribución por mes
    meses = [
        'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
        'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'
    ]
    sns.countplot(x=data[col].dt.month, order=range(1, 13), ax=axes[1], color='steelblue')
    axes[1].set_title('Distribución por mes', fontsize=12, fontweight='bold')
    axes[1].set_xlabel('Mes', fontsize=10)
    axes[1].set_ylabel('Cantidad de registros', fontsize=10)
    axes[1].set_xticks(range(12))
    axes[1].set_xticklabels(meses, rotation=45)

    # Distribución por día de la semana
    dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
    sns.countplot(x=data[col].dt.dayofweek, order=range(7), ax=axes[2], color='steelblue')
    axes[2].set_title('Distribución por día de la semana', fontsize=12, fontweight='bold')
    axes[2].set_xlabel('Día de la semana', fontsize=10)
    axes[2].set_ylabel('Cantidad de registros', fontsize=10)
    axes[2].set_xticks(range(7))
    axes[2].set_xticklabels(dias)

    plt.tight_layout()
    plt.show()
# Out:
# ======================================================================
# ANÁLISIS DE: MATCH_DATE
# ======================================================================
#
# Fecha mínima: 2026-06-11 00:00:00
# Fecha máxima: 2026-07-31 00:00:00
# Fecha con más registros jugador-partido: 2026-06-30 00:00:00 (1560 registros)

# %% [markdown]
# # Análisis bivariante

# %% [markdown]
# ## 10. Análisis bivariante numérico

# %%
data[columns_numerical].corr() # Calcula la matriz de correlación entre las variables numéricas.
# Out:
#                           age  market_value_eur  minutes_played     goals  \
# age                  1.000000         -0.068914       -0.022833 -0.036548
# market_value_eur    -0.068914          1.000000        0.017773  0.093392
# minutes_played      -0.022833          0.017773        1.000000  0.219311
# goals               -0.036548          0.093392        0.219311  1.000000
# assists             -0.027272          0.081924        0.215138  0.094499
# expected_goals_xg   -0.042648          0.100588        0.214486  0.150348
# pass_accuracy       -0.087443          0.019973        0.047211 -0.009224
# distance_covered_km -0.035127          0.025671        0.977282  0.220416
# player_rating       -0.038601          0.075153        0.837226  0.217196
#
#                       assists  expected_goals_xg  pass_accuracy  \
# age                 -0.027272          -0.042648      -0.087443
# market_value_eur     0.081924           0.100588       0.019973
# minutes_played       0.215138           0.214486       0.047211
# goals                0.094499           0.150348      -0.009224
# assists              1.000000           0.096611       0.026117
# expected_goals_xg    0.096611           1.000000      -0.022587
# pass_accuracy        0.026117          -0.022587       1.000000
# distance_covered_km  0.221692           0.215408       0.073629
# player_rating        0.204418           0.193343       0.074662
#
#                      distance_covered_km  player_rating
# age                            -0.035127      -0.038601
# market_value_eur                0.025671       0.075153
# minutes_played                  0.977282       0.837226
# goals                           0.220416       0.217196
# assists                         0.221692       0.204418
# expected_goals_xg               0.215408       0.193343
# pass_accuracy                   0.073629       0.074662
# distance_covered_km             1.000000       0.837282
# player_rating                   0.837282       1.000000

# %%
matriz_correlaciones = data[columns_numerical].corr().round(2)

plt.figure(figsize=(10, 8))
sns.heatmap(
    matriz_correlaciones,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    vmin=-1,
    vmax=1,
    linewidths=0.5
)
plt.title('Matriz de correlaciones')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.pairplot(data[columns_numerical])
plt.show()

# %% [markdown]
# ## 11. Análisis bivariante categórico

# %%
# Define aquí las dos columnas que quieres cruzar
columna_filas = 'tournament_stage'
columna_columnas = 'match_result'

# Crosstab con conteos absolutos
crosstab = pd.crosstab(
    data[columna_filas],
    data[columna_columnas]
).astype(int)

valor_min = crosstab.values.min()
valor_max = crosstab.values.max()

plt.figure(figsize=(12, 8))
sns.heatmap(
    crosstab,
    annot=True,
    fmt='d',
    cmap='RdBu_r',
    vmin=valor_min,
    vmax=valor_max,
    linewidths=2,
    linecolor='white',
    cbar_kws={'shrink': 0.85}
)
plt.title(f'Crosstab entre {columna_filas} y {columna_columnas}', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Define aquí las dos columnas que quieres cruzar
columna_filas = 'position'
columna_columnas = 'match_result'

plt.figure(figsize=(12, 8))
sns.countplot(
    data=data,
    x=columna_filas,
    hue=columna_columnas,
    order=data[columna_filas].value_counts().index,
    hue_order=data[columna_columnas].value_counts().index,
    palette='tab20'
)
plt.title(f'Diagrama de barras entre {columna_filas} y {columna_columnas}', fontsize=14, fontweight='bold')
plt.xlabel(columna_filas, fontsize=10)
plt.ylabel('Conteo', fontsize=10)
plt.xticks(rotation=45, ha='right')
plt.legend(title=columna_columnas, bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Análisis categórico + numérico

# %%
# Define aquí una variable categórica y una numérica
columna_categorica = 'position'
columna_numerica = 'player_rating'

print(f'Variable categórica: {columna_categorica}')
print(f'Variable numérica: {columna_numerica}')

# Boxplot comparativo por categoría
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=data,
    x=columna_categorica,
    y=columna_numerica,
    color='steelblue'
)
plt.title(f'Boxplot de {columna_numerica} por {columna_categorica}', fontsize=14, fontweight='bold')
plt.xlabel(columna_categorica, fontsize=10)
plt.ylabel(columna_numerica, fontsize=10)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Histogramas en subplots separados por categoría
categorias = data[columna_categorica].dropna().unique()
num_categorias = len(categorias)
num_columnas = 2
num_filas = (num_categorias + num_columnas - 1) // num_columnas

fig, axes = plt.subplots(num_filas, num_columnas, figsize=(14, 4 * num_filas))
axes = axes.flatten() if num_categorias > 1 else [axes]

for i, categoria in enumerate(categorias):
    subset = data[data[columna_categorica] == categoria]
    sns.histplot(
        data=subset,
        x=columna_numerica,
        kde=True,
        color='steelblue',
        ax=axes[i]
    )
    axes[i].set_title(f'{columna_categorica} = {categoria}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(columna_numerica, fontsize=10)
    axes[i].set_ylabel('Frecuencia', fontsize=10)

for j in range(num_categorias, len(axes)):
    axes[j].axis('off')

fig.suptitle(f'Histogramas de {columna_numerica} por {columna_categorica}', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Variable categórica: position
# Variable numérica: player_rating

# %% [markdown]
# ## 13. Análisis temporal + categórico/numérico

# %%
# Define aquí una variable numérica y una categórica para analizar su evolución temporal
columna_numerica = 'player_rating'
columna_categorica = 'match_result'
columna_tiempo = 'match_date'

print(f'Variable numérica: {columna_numerica}')
print(f'Variable categórica: {columna_categorica}')
print(f'Variable temporal: {columna_tiempo}')

# Evolución temporal de la calificación promedio por fecha
serie_numerica = data.groupby(columna_tiempo)[columna_numerica].mean().reset_index()

plt.figure(figsize=(12, 5))
sns.lineplot(
    data=serie_numerica,
    x=columna_tiempo,
    y=columna_numerica,
    color='steelblue'
)
plt.title(f'Evolución temporal del promedio de {columna_numerica}', fontsize=14, fontweight='bold')
plt.xlabel(columna_tiempo, fontsize=10)
plt.ylabel(f'Promedio de {columna_numerica}', fontsize=10)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Evolución temporal del conteo de registros por resultado
serie_categorica = (
    data.groupby([columna_tiempo, columna_categorica])
        .size()
        .reset_index(name='Conteo')
)

categorias = serie_categorica[columna_categorica].dropna().unique()
num_categorias = len(categorias)
num_columnas = 3
num_filas = (num_categorias + num_columnas - 1) // num_columnas

fig, axes = plt.subplots(
    num_filas,
    num_columnas,
    figsize=(16, 4 * num_filas),
    sharex=True,
    sharey=False
)
axes = axes.flatten() if num_categorias > 1 else [axes]

for i, categoria in enumerate(categorias):
    subset = serie_categorica[serie_categorica[columna_categorica] == categoria]
    sns.lineplot(
        data=subset,
        x=columna_tiempo,
        y='Conteo',
        ax=axes[i],
        color='steelblue'
    )
    axes[i].set_title(f'{columna_categorica} = {categoria}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(columna_tiempo, fontsize=10)
    axes[i].set_ylabel('Conteo', fontsize=10)
    axes[i].tick_params(axis='x', rotation=45)

for j in range(num_categorias, len(axes)):
    axes[j].axis('off')

fig.suptitle(f'Evolución temporal de {columna_categorica} por subgrupos', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Variable numérica: player_rating
# Variable categórica: match_result
# Variable temporal: match_date

# %% [markdown]
# # Cinco preguntas de análisis

# %% [markdown]
# ## Pregunta 1
#
# ¿Los jugadores con mayor cantidad de goles esperados (`expected_goals_xg`) suelen marcar más goles?

# %%
correlacion_xg_goles = data[['expected_goals_xg', 'goals']].corr().round(3)
display(correlacion_xg_goles)

sns.pairplot(data[['expected_goals_xg', 'goals']])
plt.show()
# Out:
#                    expected_goals_xg  goals
# expected_goals_xg               1.00   0.15
# goals                           0.15   1.00

# %% [markdown]
# Conclusión: Existe una relación positiva, pero débil, entre los goles esperados y los goles marcados. La correlación es aproximadamente 0.150, por lo que un mayor `expected_goals_xg` se asocia con más goles, aunque por sí solo no explica gran parte de su variación.

# %% [markdown]
# ## Pregunta 2
#
# ¿Cómo cambia la calificación del jugador (`player_rating`) según su posición?

# %%
calificacion_por_posicion = data.groupby('position')['player_rating'].describe().round(3)
display(calificacion_por_posicion)

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=data,
    x='position',
    y='player_rating',
    color='steelblue'
)
plt.title('Calificación del jugador por posición', fontsize=14, fontweight='bold')
plt.xlabel('Posición')
plt.ylabel('Calificación del jugador')
plt.tight_layout()
plt.show()
# Out:
#               count   mean    std  min  25%  50%  75%  max
# position
# Defender    18900.0  3.790  3.097  0.0  0.0  5.6  6.4  9.4
# Forward     12600.0  3.884  3.154  0.0  0.0  5.7  6.5  9.2
# Goalkeeper   6300.0  2.068  2.955  0.0  0.0  0.0  5.7  8.6
# Midfielder  16800.0  3.861  3.131  0.0  0.0  5.6  6.5  9.2

# %% [markdown]
# Conclusión: Los delanteros presentan el promedio más alto de calificación (3.884), seguidos de los mediocampistas (3.861) y defensores (3.790). Los porteros tienen un promedio considerablemente menor (2.068) y una mediana de 0, por lo que la distribución de su calificación difiere de la de las demás posiciones.

# %% [markdown]
# ## Pregunta 3
#
# ¿Los jugadores de equipos ganadores obtienen mejores calificaciones que los de equipos que empatan o pierden?

# %%
calificacion_por_resultado = data.groupby('match_result')['player_rating'].describe().round(3)
display(calificacion_por_resultado)

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=data,
    x='match_result',
    y='player_rating',
    color='steelblue'
)
plt.title('Calificación del jugador según el resultado', fontsize=14, fontweight='bold')
plt.xlabel('Resultado del partido')
plt.ylabel('Calificación del jugador')
plt.tight_layout()
plt.show()
# Out:
#                 count   mean    std  min  25%  50%  75%  max
# match_result
# D             14352.0  3.605  3.129  0.0  0.0  5.4  6.3  8.9
# L             20124.0  3.606  3.129  0.0  0.0  5.4  6.3  9.2
# W             20124.0  3.685  3.200  0.0  0.0  5.6  6.5  9.4

# %% [markdown]
# Conclusión: Los jugadores de equipos ganadores tienen una calificación media un poco superior (3.685) a la de quienes empatan (3.605) o pierden (3.606). La diferencia es muy pequeña, aunque la mediana también aumenta de 5.4 a 5.6 en las victorias.

# %% [markdown]
# ## Pregunta 4
#
# ¿La distancia recorrida por los jugadores cambia según su posición?

# %%
distancia_por_posicion = data.groupby('position')['distance_covered_km'].describe().round(3)
display(distancia_por_posicion)

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=data,
    x='position',
    y='distance_covered_km',
    color='steelblue'
)
plt.title('Distancia recorrida según la posición', fontsize=14, fontweight='bold')
plt.xlabel('Posición')
plt.ylabel('Distancia recorrida (km)')
plt.tight_layout()
plt.show()
# Out:
#               count   mean    std  min  25%  50%  75%   max
# position
# Defender    18900.0  3.993  3.860  0.0  0.0  2.9  7.8  13.0
# Forward     12600.0  4.125  3.980  0.0  0.0  3.1  8.0  13.0
# Goalkeeper   6300.0  2.411  3.494  0.0  0.0  0.0  6.3  11.0
# Midfielder  16800.0  4.499  4.264  0.0  0.0  3.2  8.6  14.0

# %% [markdown]
# Conclusión: Los mediocampistas recorren la mayor distancia promedio (4.499 km), seguidos de los delanteros (4.125 km) y defensores (3.993 km). Los porteros presentan la menor distancia promedio (2.411 km), lo cual evidencia diferencias de desplazamiento según la posición.

# %% [markdown]
# ## Pregunta 5
#
# ¿Cómo evoluciona la calificación promedio de los jugadores durante el torneo?

# %%
calificacion_por_fecha = (
    data.groupby('match_date')['player_rating']
        .mean()
        .reset_index()
)
display(calificacion_por_fecha)

plt.figure(figsize=(12, 5))
sns.lineplot(
    data=calificacion_por_fecha,
    x='match_date',
    y='player_rating',
    color='steelblue'
)
plt.title('Evolución de la calificación promedio durante el torneo', fontsize=14, fontweight='bold')
plt.xlabel('Fecha del partido')
plt.ylabel('Calificación promedio')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#    match_date  player_rating
# 0  2026-06-11       3.576099
# 1  2026-06-12       3.638158
# 2  2026-06-13       3.689530
# 3  2026-06-14       3.599774
# 4  2026-06-15       3.594231
# 5  2026-06-16       3.599308
# 6  2026-06-17       3.652030
# 7  2026-06-18       3.564652
# 8  2026-06-19       3.628261
# 9  2026-06-20       3.633580
# 10 2026-06-21       3.590962
# 11 2026-06-22       3.631410
# 12 2026-06-23       3.661437
# 13 2026-06-24       3.640919
# 14 2026-06-25       3.560752
# 15 2026-06-26       3.630641
# 16 2026-06-27       3.609066
# 17 2026-06-28       3.656685
# 18 2026-06-29       3.655695
# 19 2026-06-30       3.626410
# 20 2026-07-01       3.700962
# 21 2026-07-02       3.676839
# 22 2026-07-03       3.624267
# 23 2026-07-04       3.689712
# 24 2026-07-05       3.615486
# 25 2026-07-06       3.689073
# 26 2026-07-07       3.629533
# 27 2026-07-08       3.661996
# 28 2026-07-09       3.678077
# 29 2026-07-10       3.609441
# 30 2026-07-11       3.633846
# 31 2026-07-12       3.685223
# 32 2026-07-13       3.656680
# 33 2026-07-14       3.543826
# 34 2026-07-15       3.587130
# 35 2026-07-16       3.624199
# 36 2026-07-17       3.670481
# 37 2026-07-18       3.664209
# 38 2026-07-19       3.638378
# 39 2026-07-20       3.633876
# 40 2026-07-21       3.616420
# 41 2026-07-22       3.659135
# 42 2026-07-23       3.620833
# 43 2026-07-24       3.615923
# 44 2026-07-25       3.626522
# 45 2026-07-26       3.652715
# 46 2026-07-27       3.656355
# 47 2026-07-28       3.650285
# 48 2026-07-29       3.612462
# 49 2026-07-30       3.623829
# 50 2026-07-31       3.646154

# %% [markdown]
# Conclusión: La calificación promedio permanece relativamente estable durante el torneo, con valores diarios entre aproximadamente 3.544 y 3.701. Aunque pasa de 3.576 en la primera fecha a 3.646 en la última, las variaciones son pequeñas y no se observa una tendencia fuerte de aumento o disminución.
